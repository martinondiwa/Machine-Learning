# %% [markdown]
# <a href="https://colab.research.google.com/github/martinondiwa/Machine-Learning/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir KNN

# %%
# !cd KNN/

# %%
# !touch nearest Neighbour

# %%
# !rm -f nearest Neighbour

# %%
# !touch Neighbourhood_Analysis
